# %%
! git pull
# Out:
# remote: Counting objects: 67, done.
# remote: Compressing objects: 100% (51/51), done.
# Unpacking objects:  43% (29/67)
# Unpacking objects:  44% (30/67)
# Unpacking objects:  47% (32/67)
# remote: Total 67 (delta 23), reused 51 (delta 10)
# Unpacking objects: 100% (67/67), done.
# From https://github.com/cliburn/STA663-2015
#    5e2161f..68b4585  master     -> origin/master
# Updating 5e2161f..68b4585
# Fast-forward
#  .../VM Instructions-checkpoint.ipynb               |   53 +
#  Labs/Lab01/.gitignore                              |    0
#  .../.ipynb_checkpoints/Solutions-checkpoint.ipynb  |  145 --
#  Labs/Lab01/Exercises.ipynb                         |  223 ---
#  ...xercises-checkpoint.ipynb => Exercises01.ipynb} |   14 +-
#  Labs/Lab02/Exercises02.ipynb                       |  282 ++++
#  Lectures/Topic01_Python_and_IPython/.gitignore     |    0
#  .../IPythonNotebookIntroduction-checkpoint.ipynb   |  304 +++-
# ...
